# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
covid = pd.read_csv("https://opendata.arcgis.com/datasets/bd4ee19bc7fc4288a20db8d5a7bd2be2_0.csv")

# %%
covid = covid.sort_values(by=['Date'])

# %%
del covid['DthCOVID19']
del covid['Outbreaks']
del covid['Test_Encounters']

# %%
covid = covid.dropna()
covid
# Out:
#          Name       Desc_        Date    Cases    Tested  Deaths  Population  \
# 0    Colorado  State Data  03/17/2020    183.0    1790.0     2.0   5694287.0
# 1    Colorado  State Data  03/18/2020    216.0    2328.0     2.0   5694287.0
# 2    Colorado  State Data  03/19/2020    277.0    2952.0     2.0   5694287.0
# 3    Colorado  State Data  03/20/2020    363.0    3680.0     4.0   5694287.0
# 4    Colorado  State Data  03/21/2020    475.0    4550.0     5.0   5694287.0
# ..        ...         ...         ...      ...       ...     ...         ...
# 120  Colorado  State Data  09/19/2020  64356.0  821128.0  2013.0   5763976.0
# 121  Colorado  State Data  09/20/2020  64857.0  828108.0  2014.0   5763976.0
# 122  Colorado  State Data  09/21/2020  65399.0  834277.0  2018.0   5763976.0
# 123  Colorado  State Data  09/22/2020  66053.0  840452.0  2025.0   5763976.0
# 124  Colorado  State Data  09/23/2020  66669.0  848906.0  2030.0   5763976.0
#
#         Rate    Hosp  Counties  ObjectId
# ...

# %%
covid_change = pd.DataFrame([covid['Date'], covid['Tested'].diff(), covid['Cases'].diff(), covid['Deaths'].diff()]).T

# %%
covid_change = covid_change.dropna()

# %%
covid_change['PositiveRate'] = covid_change['Cases'] / covid_change['Tested'] * 100

# %%
positive_rate = go.Figure(data=[go.Bar(x=covid_change['Date'], y=covid_change['PositiveRate'], name='% Tests that are positive')])
positive_rate.update_yaxes(title_text="<b>Percent</b>", showgrid=False)
positive_rate.update_xaxes(title_text="<b>Date</b>", showgrid=False)
positive_rate.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Bar(x=covid_change['Date'], y=covid_change['Tested'], name='Tests'), secondary_y=False)
fig.add_trace(go.Scatter(x=covid_change['Date'], y=covid_change['Cases'], name='Cases'), secondary_y=True)
fig.update_yaxes(title_text="<b>Tests that Day</b>", secondary_y=False, showgrid=False)
fig.update_yaxes(title_text="<b>Positive Tests that Day</b>", secondary_y=True, showgrid=False)
fig.update_xaxes(title_text="<b>Date</b>", showgrid=False)
fig

# %%
deaths = go.Figure(data=[go.Bar(x=covid_change['Date'], y=covid_change['Deaths'], name='Deaths')])
deaths.update_yaxes(title_text="<b>Deaths that Day</b>", showgrid=False)
deaths.update_xaxes(title_text="<b>Date</b>", showgrid=False)
deaths.show()

# %% [markdown]
# ## Some good news
#
# Deaths have gone down significantly, and have stabilized. This could be due to
#
#  - Doctors having better health procedures for saving lives
#  - Better safety protocols for those at high risk
#
# Probably many other things I'm not considering. Thanks for checking out my stats! This all comes from [CDPHE](https://hub.arcgis.com/datasets/6811473e86fe4e2cb6af10d54c15ecee_0).
